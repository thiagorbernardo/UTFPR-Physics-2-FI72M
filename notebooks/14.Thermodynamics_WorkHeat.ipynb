# %% [markdown]
# # Aula 14: Termodinâmica - Calor e trabalho

# %% [markdown]
# ## Calor e Trabalho
#
# $W = F d$
#
#
# Variáveis da termodinâmica:
# Temperatura - T
# Volume - V
# Pressão - P
#
# Vamos usar
#
# $P = F / A$
#
# Supondo que o êmbolo se move lentamente
#
# $\Delta x = dx$
#
# Trabalho infinitesimal é $dW = F dx$
#
# Com F constante
#
# $dW = P A dx$
#
# $dW = P dV$

# %% [markdown]
# O trabalho realizado pelo sistema na espansão
#
# $W = \int_{V_i}^{V_f} P \, dV$
#
# P pode depender da temepratura e volume, ou seja, depende do caminho realizado entre a situação inicial e final
#
# Expansão:
#
# $V_f > V_A$
#
# $W > 0$
#
# Trabalho realizado pelo sistema!
#
# Compressão:
#
# $V_A > V_f$
#
# $W < 0$

# %% [markdown]
# Duas situações:
#
# 1. Gás se expande, temperatura aumenta e a pressão se mantém constante
#
# *Gráfico reta*
#
# $V_f > V_i$
#
# $P_f = P_i$
#
# $T_f > T_i$
#
# 2. Gás se expande, pressão diminui e a temperatura se mantém inalterada
#
# *Gráfico curva*
#
# $V_f > V_i$
#
# $P_f < P_i$
#
# $T_f = T_i$
#
# Todo calor é transformado em trabalho
#
# Exemplos - foto halliday

# %% [markdown]
# ## 1°Lei da termodinâmica
#
# $\Delta E_{int} = Q - W$
#
# A $E_{int}$ é dada pela soma das contribuiçõs das Energias
#
# $E_{int}^f - E_{int}^i= Q - W$
#
# $Q - E_{int}^i = E_{int}^f + W$
#
# Primeiro termo $E_i$, segundo $E_f$
#
# $d E_{int} = \delta Q - \delta W$

# %% [markdown]
# ## Processod Adiabáticos
#
# Sistema com paredes adiabáticas (isolante térmico)
#
# <img src="https://i.ytimg.com/vi/HDAGPNjZNDg/maxresdefault.jpg" alt="Aula13.2" width="400" height="400"/>
#
# ### Expansão adiabática
#
# $Q = 0$
#
# $V_i < V_f$
#
# $p_i > p_f$
#
# Trabalho realizado pelo sistema
#
# $\Delta E_{int} = Q - W < 0 $
#
# $T_i > T_f$
#
# ### Compressão adiabática
#
# $Q = 0$
#
# $V_i < V_f$
#
# $p_i > p_f$
#
# Trabalho realizado sobre sistema
#
# $\Delta E_{int} = Q - W > 0 $
#
# $T_i < T_f$

# %% [markdown]
# ## Processo Isocórico $V = cte$
#
# Sistema com parede diatérmica
#
# ### 1° Sistema ganha calor
#
# $V_i = V_f$
#
# $p_i < p_f$
#
# $T_i < T_f$
#
# $Q > 0$
#
# $W = 0$
#
# $\Delta E_{int} = Q - W > 0 $
#
#
# ### 2° Sistema perde calor
#
# $V_i = V_f$
#
# $p_i > p_f$
#
# $T_i > T_f$
#
# $Q < 0$
#
# $W = 0$
#
# $\Delta E_{int} = Q - W < 0 $

# %% [markdown]
# ## Processo Isotérmico $T = cte$
#
# Sistema com parede diatérmica
#
# ### Expansão isotérmica - ganha calor
#
# $V_i < V_f$
#
# $p_i > p_f$
#
# $T_i = T_f$
#
# $Q > 0$
#
# $W = 0$
#
# $\Delta E_{int} = Q - W = 0 $

# %% [markdown]
# ## Processo Isobárico $p = cte$
#
# Sistema com parede diatérmica
#
# ### Expansão isotérmica - ganha calor
#
# $V_i < V_f$
#
# $p_i =  p_f$
#
# $T_i = T_f$
#
# $Q > 0$
#
# $W = 0$
#
# $\Delta E_{int} = Q - W = 0 $

# %% [markdown]
# ## Expansão livre
#
#
# $V_i < V_f$
#
# $p_i >  p_f$
#
# $T_i = T_f$
#
# $Q = 0$
#
# $W = 0$
#
# $\Delta E_{int} = Q - W = 0 $

# %% [raw]
# [Ex 30 e 45](../assets/aula11/ex1.jpeg)
#
# [Ex 49](../assets/aula11/ex2.jpeg)
